# %%
import nltk.data
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from stemming.porter2 import stem
import wikipedia
from gensim import corpora, models

# %%
# function to parse sentences to words and remove stopwords from sentence
def sentence_to_wordlist( sentence, remove_stopwords=True ):
    # Function to convert a document to a sequence of words,
    # optionally removing stop words.  Returns a list of words.
    #
    # 1. Remove HTML
    text = BeautifulSoup(sentence).get_text()
    #  
    # 2. Remove non-letters
    text = re.sub("[^a-zA-Z]"," ",text)
    #
    # 3. Convert words to lower case and split them
    words = text.lower().split()
    #
    # 4. Optionally remove stop words (false by default)
    if remove_stopwords:
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
    #
    # 5. Return a list of words
    return(words)

# %%
# function to parse text to sentences using tokenizer mentioned above
def text_to_sentences(text,tokenizer,remove_stopwords=True):
    raw_sentences = tokenizer.tokenize(text.strip())
    sentences = []
    for raw_sentence in raw_sentences:
        # If a sentence is empty, skip it
        if len(raw_sentence) > 0:
            # Otherwise, call review_to_wordlist to get a list of words
            sentences.append( sentence_to_wordlist( raw_sentence, \
              remove_stopwords ))
    #
    # Return the list of sentences (each sentence is a list of words,
    # so this returns a list of lists
    return sentences

# %%
# tokenize to sentences based on the notations followed in english literature
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

#import wikipedia page for 
content = wikipedia.page('barack').content
#print content

#tokenise content and store it in text
sentences = []
sentences = text_to_sentences(content, tokenizer)
print sentences
# Out:
# [[u'barack', u'hussein', u'obama', u'ii', u'us', u'b', u'r', u'k', u'hu', u'se', u'n', u'b', u'b', u'rahk', u'hoo', u'sayn', u'oh', u'bah', u'born', u'august', u'american', u'politician', u'served', u'th', u'president', u'united', u'states'], [u'first', u'african', u'american', u'served', u'president', u'well', u'first', u'born', u'outside', u'contiguous', u'united', u'states'], [u'previously', u'served', u'u', u'senate', u'representing', u'illinois', u'illinois', u'state', u'senate'], [u'obama', u'born', u'honolulu', u'hawaii', u'two', u'years', u'territory', u'admitted', u'union', u'th', u'state'], [u'grew', u'mostly', u'hawaii', u'also', u'spent', u'one', u'year', u'childhood', u'washington', u'state', u'four', u'years', u'indonesia'], [u'graduating', u'columbia', u'university', u'worked', u'community', u'organizer', u'chicago'], [u'obama', u'enrolled', u'harvard', u'law', u'school', u'first', u'black', u'president', u'harvard', u'law', u'review'], [u'graduation', u'became', u'civil', u'rights', u'attorney', u'professor', u'teaching', u'constitutional', u'law', u'university', u'chicago', u'law', u'school'], [u'obama', u'represented', u'th', u'district', u'three', u'terms', u'illinois', u'senate', u'ran', u'u', u'senate'], [u'obama', u'received', u'national', u'attention', u'unexpected', u'march', u'primary', u'win', u'well', u'received', u'july', u'democratic', u'national', u'convention', u'keynote', u'address', u'landslide', u'november', u'election', u'senate'], [u'obama', u'nominated', u'president', u'year', u'campaign', u'began', u'close', u'primary', u'campaign', u'hillary', u'clinton'], [u'elected', u'republican', u'john', u'mccain', u'inaugurated', u'january'], [u'nine', u'months', u'later', u'obama', u'named', u'nobel', u'peace', u'prize', u'laureate'], [u'first', u'two', u'years', u'office', u'obama', u'signed', u'landmark', u'legislation', u'democratic', u'president', u'since', u'lbj', u'great', u'society'], [u'main', u'reforms', u'patient', u'protection', u'affordable', u'care', u'act', u'often', u'referred', u'obamacare', u'dodd', u'frank', u'wall', u'street', u'reform', u'consumer', u'protection', u'act', u'ask', u'tell', u'repeal', u'act'], [u'american', u'recovery', u'reinvestment', u'act', u'tax', u'relief', u'unemployment', u'insurance', u'reauthorization', u'job', u'creation', u'act', u'served', u'economic', u'stimulus', u'amidst', u'great', u'recession', u'gop', u'regained', u'control', u'house', u'representatives'], [u'lengthy', u'debate', u'national', u'debt', u'limit', u'obama', u'signed', u'budget', u'control', u'american', u'taxpayer', u'relief', u'acts'], [u'foreign', u'policy', u'obama', u'increased', u'u', u'troop', u'levels', u'afghanistan', u'reduced', u'nuclear', u'weapons', u'u', u'russian', u'new', u'start', u'treaty', u'ended', u'military', u'involvement', u'iraq', u'war'], [u'ordered', u'military', u'involvement', u'libya', u'opposition', u'muammar', u'gaddafi', u'military', u'operation', u'resulted', u'death', u'osama', u'bin', u'laden'], [u'winning', u'election', u'mitt', u'romney', u'obama', u'sworn', u'second', u'term'], [u'second', u'term', u'obama', u'promoted', u'greater', u'inclusiveness', u'lgbt', u'americans', u'administration', u'filing', u'briefs', u'urged', u'supreme', u'court', u'strike', u'sex', u'marriage', u'bans', u'unconstitutional', u'united', u'states', u'v', u'windsor', u'obergefell', u'v', u'hodges'], [u'obama', u'also', u'advocated', u'gun', u'control', u'response', u'sandy', u'hook', u'elementary', u'school', u'shooting', u'issued', u'wide', u'ranging', u'executive', u'actions', u'concerning', u'climate', u'change', u'immigration'], [u'foreign', u'policy', u'obama', u'ordered', u'military', u'intervention', u'iraq', u'response', u'gains', u'made', u'isil', u'withdrawal', u'iraq', u'continued', u'process', u'ending', u'u', u'combat', u'operations', u'afghanistan', u'promoted', u'discussions', u'led', u'paris', u'agreement', u'global', u'climate', u'change', u'initiate ...

# %%
# Create p_stemmer of class PorterStemmer
p_stemmer = PorterStemmer()
# stem token
documents = [[stem(word) for word in sentence] for sentence in sentences]


# Dictionary() function creates document-term-matrix and assign unique id to tokens
dictionary = corpora.Dictionary(documents)

#dictionary should be converted to bag of words
corpus = [dictionary.doc2bow(sentence) for sentence in documents]

# %%
#construct lda model which gives top 3 relevant topics
ldamodel = models.ldamodel.LdaModel(corpus, num_topics=3, id2word = dictionary, passes=20)
print(ldamodel.print_topics(num_topics=3, num_words=3))

#Each generated topic is separated by a comma, 
#Within each topic are the three most probable words to appear in that topic
# Adjusting the model’s number of topics and passes is important for getting a good result
# Out:
# [(0, u'0.023*"obama" + 0.008*"u" + 0.008*"elect"'), (1, u'0.038*"obama" + 0.013*"act" + 0.012*"presid"'), (2, u'0.034*"obama" + 0.013*"presid" + 0.009*"state"')]
